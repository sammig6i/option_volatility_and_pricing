# %% [markdown]
# 1. Using the grid below, draw the parity graphs (the value at expiration) for the following positions:
#
#    a.   long a 65 call
#
#    b.   short a 70 call
#
#    c.   long a 75 put
#
#    d.   short an 80 put

# %% [markdown]
# ![Screenshot 2024-05-09 at 7.59.19 PM.png](attachment:71a5ac7f-84dc-4db3-8d34-1055c7958f96.png)

# %% [markdown]
# 2.  Using the grid below, draw the parity graphs (the value at expiration) for the following
#             combination positions:
#
#
#     a.   long a 70 put and long a 75 call
#
#
#     b.   long an 80 put and short an 80 call
#
#
#     c.   short two 65 calls”

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.45.16 PM.png](attachment:e571270d-7935-44c1-b6ec-2d56442566ad.png)

# %% [markdown]
# 3. The slopes of the various option and underlying positions at expiration can be summarized
#             as follows:

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.46.07 PM.png](attachment:6f77b341-1e83-47a0-971d-399bdc28f2e3.png)

# %% [markdown]
# For each position below, what is the slope of the expiration graph over the given
#             underlying price intervals? From these slopes, sketch the shape of the expiration
#             P&L graph. (The sketch need not be to scale—the approximate shape is sufficient.)

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.47.16 PM.png](attachment:cc82dab3-27e9-4bb6-bccd-71e4041dbd1c.png)

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.47.29 PM.png](attachment:ea47a855-9284-4e84-9397-bf1860e279b7.png)

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.47.42 PM.png](attachment:36a7349d-74c3-4f5c-9ac3-9826dec0be9f.png)

# %% [markdown]
# 4.  Using the underlying price and option prices below, draw the expiration profit and
#             loss graph for the given positions. What are the breakeven prices for each position?
#
#
#          underlying price = 72.00

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.52.39 PM.png](attachment:cff3fc2b-08ab-4f43-8a66-5afd14d9104c.png)

# %% [markdown]
# a.   long a March 70 call
#
#
# b.   short a March 65 put
#
#
# c.   long a March 75 put
#
# d.   short a March 80 call

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.54.25 PM.png](attachment:65915c62-b113-4465-b7d3-9c82f830bd86.png)

# %% [markdown]
# e.  long a March 70 call and short a March 80 call
#
#
# f.   long a March 80 put and short 2 March 70 puts
#
#
# g.   short a March 70 call and long a March 70 put

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.55.19 PM.png](attachment:af34cedd-c038-4d74-b861-6d0cce9d7bdb.png)

# %% [markdown]
# h.  long a March 70 put and long an underlying contract
#
#
# i.   long a March 65 put and short a March 75 call
#
#
# j.   long a March 70 call and long a March 70 put

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.55.48 PM.png](attachment:7631b57e-c865-4ab9-bc18-0f6964090ab5.png)

# %% [markdown]
# 5.  You have the position and contract prices shown in the following chart.
#
#
# a.   What will be your profit or loss if the underlying contract at expiration is trading
#             at a price of 70.00?

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.56.23 PM.png](attachment:4b826c79-e138-4bb0-9c70-c8df560fa070.png)

# %% [markdown]
# b.   What is the expiration slope of your position.

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.57.15 PM.png](attachment:5a5abd5d-8bfc-4ca4-8577-d5cc184013ba.png)

# %% [markdown]
# c.   Using the slopes of your position and the P&L at 70.00, what will be your profit
#             or loss at expiration at the following underlying prices?

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.57.51 PM.png](attachment:85ffeeab-9526-4b03-86c7-6fe50d108bfe.png)

# %% [markdown]
# d.   To the nearest .01, what are the breakeven prices for the entire position?
#
# e.   On the following grid, draw the value of your position at expiration.

# %% [markdown]
# ![Screenshot 2024-05-14 at 11.58.40 PM.png](attachment:ef13b68e-4532-4ab9-8202-2b4595cc2e98.png)
